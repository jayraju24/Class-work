# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
experiance=np.random.randint(1,11,50)
salary=experiance*8+np.random.randint(0,3,50)
df=pd.DataFrame({'experiance':experiance,'salary':salary})
print("sample  Data")
print(df.head())
# Out:
# sample  Data
#    experiance  salary
# 0           7      58
# 1           4      34
# 2           8      65
# 3           5      40
# 4           7      57

# %%
x=df[['experiance']]
y=df['salary']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("intercept:",model.intercept_)
print(" slope:",model.coef_[0],"\n")
# Out:
# intercept: 0.6300110334681932
#  slope: 8.066384700257446

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([24.82916513, 32.89554983, 73.22747334, 40.96193453, 65.16108864,
#        57.09470394, 81.29385804,  8.69639573, 40.96193453, 16.76278043])

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("R2 Score:",r2)
# Out:
# Mean Absolute Error: 0.7909893343140821
# Mean Squared Error: 0.8065449080551021
# Root Mean Squared Error: 0.8980784531738316
# R2 Score: 0.998445034783676

# %%
plt.scatter(x,y,color='blue',label='actual')
plt.plot(x,model.predict(x),color='red',label='Regression Line ')
plt.xlabel('experiance')
plt.ylabel('salary')
plt.title('Linear Regression')
plt.legend()
plt.show()
